# %%
import pandas as pd
import tensorflow as tf
pd.set_option('display.max_columns', 500)

# %%
my_data = pd.read_csv(filepath_or_buffer="north_carolina_bicycle_crash_data_heatmap_.csv", sep=";")

# %%
pd.set_option('display.max_columns', 500)

# %%
my_data
# Out:
#                           Geo Point  \
# 0      34.7206969157, -76.659721954
# 1     35.0454269114, -78.9244486567
# 2     35.6320950402, -78.8518026659
# 3     35.7723420782, -78.6459626106
# 4     35.9034171433, -77.5620822881
# 5     36.3120911946, -78.5922266237
# 6     36.0886491026, -79.8329569863
# 7     36.2196801318, -79.7879929808
# 8     35.7849570786, -78.6869026239
# 9     35.7860370802, -78.6627526163
# 10     35.8448440959, -78.579912594
# 11    36.0647230985, -79.7937029738
# 12    35.9446211441, -77.7962673613
# 13     35.7864070679, -79.009768721
# 14    36.0460071343, -78.6980826407
# 15    36.2815572703, -76.2234418972
# 16    34.6289398182, -78.9881926553
# 17    35.9239650943, -79.0903527532
# 18    34.6956898656, -78.0103223638
# 19    35.0705068478, -80.8808092442
# 20    35.7237620933, -77.9119023851
# 21    35.2458948846, -80.8974872592
# 22    35.1377168615, -80.8792372479
# 23    35.1999568807, -80.7384132095
# 24    35.2406648878, -80.7587132179
# ...

# %%
my_data["BikeInjury"]

df = my_data.loc[my_data["BikeInjury"] == "C: Possible Injury"]
df.shape
# Out:
# (2916, 66)

# %%
# Out:
# (364, 66)
